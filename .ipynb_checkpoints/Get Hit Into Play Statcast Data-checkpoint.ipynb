# %%
from pybaseball_edited import statcast_bip
import pandas as pd

# %%
df = pd.DataFrame(statcast_bip(start_dt='2021-04-01', end_dt='2021-11-02'))
# Out:
# This is a large query, it may take a moment to complete
# C:\Anaconda\lib\site-packages\pybaseball_edited\statcast.py:68: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# 100%|████████████████████████████████████████████████████████████████████████████████| 216/216 [00:44<00:00,  4.89it/s]

# %%
df.head(20)
# Out:
#    pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 26         FF 2021-11-02           93.7           1.39           6.72
# 69         FF 2021-11-02           92.9           1.38           6.72
# 29         FF 2021-11-02           94.6           1.31           6.73
# 76         FF 2021-11-02           93.8           1.36           6.74
# 28         FF 2021-11-02           93.4           1.37           6.86
# 8          FF 2021-11-02           93.8           1.35           6.79
# 55         FF 2021-11-02           93.2           1.35           6.74
# 62         CH 2021-11-02           87.7          -2.39           5.26
# 6          CU 2021-11-02           84.4          -2.51           5.23
# 20         CU 2021-11-02           82.5          -2.68           5.24
# 78         CU 2021-11-02           83.0           -2.6           5.31
# 63         FF 2021-11-02           96.0           1.69           6.33
# 44         SL 2021-11-02           85.8           1.95           6.11
# 48         FF 2021-11-02           97.1            2.0           6.19
# 17         FF 2021-11-02           94.2          -0.45           5.93
# 18         CU 2021-11-02           80.3          -0.61           6.07
# 59         FF 2021-11-02           93.6          -0.34           6.06
# 15         FF 2021-11-02           98.3           1.78           6.31
# 45         FF 2021-11-02           97.0           1.52            6.5
# 32         FF 2021-11-02           97.8           1.83            6.3
#
#           player_name  batter  pitcher     events    description  ...  \
# 26      Gurriel, Yuli  493329   519293  field_out  hit_into_play  ...
# 69      Gurriel, Yuli  493329   519293        NaN           foul  ...
# 29    Alvarez, Yordan  670541   519293  field_out  hit_into_play  ...
# 76    Alvarez, Yordan  670541   519293        NaN           foul  ...
# 28     Correa, Carlos  621043   519293  field_out  hit_into_play  ...
# 8   Brantley, Michael  488726   519293     single  hit_into_play  ...
# 55  Brantley, Michael  488726   519293        NaN           foul  ...
# 62     Rosario, Eddie  592696   554340  field_out  hit_into_play  ...
# 6     Swanson, Dansby  621020   554340  field_out  hit_into_play  ...
# 20   d'Arnaud, Travis  518595   554340  field_out  hit_into_play  ...
# 78   d'Arnaud, Travis  518595   554340        NaN           foul  ...
# 63   Gonzalez, Marwin  503556   554431        NaN           foul  ...
# 44      Díaz, Aledmys  649557   554431        NaN           foul  ...
# 48      Díaz, Aledmys  649557   554431        NaN           foul  ...
# 17      Albies, Ozzie  645277   519151  field_out  hit_into_play  ...
# 18      Pederson, Joc  592626   519151  field_out  hit_into_play  ...
# 59       Duvall, Adam  594807   519151  field_out  hit_into_play  ...
# 15       Tucker, Kyle  663656   554431  field_out  hit_into_play  ...
# 45       Tucker, Kyle  663656   554431        NaN           foul  ...
# 32      Gurriel, Yuli  493329   554431  field_out  hit_into_play  ...
#
#     fld_score  post_away_score  post_home_score  post_bat_score  \
# 26          7                7                0               0
# 69          7                7                0               0
# 29          7                7                0               0
# 76          7                7                0               0
# 28          7                7                0               0
# 8           7                7                0               0
# 55          7                7                0               0
# 62          0                7                0               7
# 6           0                7                0               7
# 20          0                7                0               7
# 78          0                7                0               7
# 63          7                7                0               0
# 44          7                7                0               0
# 48          7                7                0               0
# 17          0                7                0               7
# 18          0                7                0               7
# 59          0                7                0               7
# 15          7                7                0               0
# 45          7                7                0               0
# 32          7                7                0               0
#
#     post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 26               7              Standard              Standard       146
# 69               7              Standard              Standard       145
# 29               7         Infield shift              Standard       140
# 76               7         Infield shift              Standard       145
# 28               7         Infield shift              Standard       147
# 8                7         Infield shift              Standard       146
# 55               7         Infield shift              Standard       147
# 62               0         Infield shift              Standard       248
# 6                0              Standard              Standard        76
# 20               0              Standard              Standard        73
# 78               0              Standard              Standard        81
# 63               7              Standard              Standard       153
# 44               7         Infield shift              Standard       314
# 48               7              Standard              Standard       152
# 17               0         Infield shift              Standard       196
# 18               0         Infield shift              Standard        27
# 59               0              Standard              Standard       200
# 15               7              Standard              Standard       150
# 45               7              Standard              Standard       156
# 32               7              Standard              Standard       145
#
#    delta_home_win_exp delta_run_exp
# 26                0.0        -0.136
# 69                0.0        -0.047
# 29             -0.001        -0.384
# 76                0.0        -0.048
# 28             -0.002        -0.272
# 8               0.002         0.327
# 55                0.0        -0.057
# 62                0.0        -0.085
# 6                 0.0        -0.114
# 20                0.0         -0.23
# 78                0.0        -0.038
# 63                0.0        -0.065
# 44                0.0           0.0
# 48                0.0        -0.057
# 17                0.0        -0.061
# 18                0.0        -0.239
# 59              0.001        -0.241
# 15             -0.004        -0.216
# 45                0.0        -0.064
# 32             -0.005        -0.443
#
# [20 rows x 92 columns]

# %%
df.shape
# Out:
# (235863, 92)

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
#        'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
#        'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
#        'woba_value', 'woba_denom', 'babip_value', 'iso_value',
#        'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
#        'delta_home_win_exp', 'delta_run_exp'],
#       dtype='object')

# %%
selected_cols = ['pitch_type', 'game_date', 'player_name', 'batter', 'pitcher', 'events',
       'description', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
       'hit_location', 'bb_type', 'balls', 'strikes', 'game_year',
       'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
       'hit_distance_sc', 'launch_speed', 'launch_angle',
       'game_pk', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
       'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name', 'bat_score', 'fld_score',
       'if_fielding_alignment', 'of_fielding_alignment']

# %%
df_core_stats = df[selected_cols]
df_core_stats = df_core_stats.loc[df['description']=='hit_into_play']
pd.Index(df_core_stats).rename('')
df_core_stats.head()
# Out:
#    pitch_type  game_date        player_name  batter  pitcher     events  \
# 26         FF 2021-11-02      Gurriel, Yuli  493329   519293  field_out
# 29         FF 2021-11-02    Alvarez, Yordan  670541   519293  field_out
# 28         FF 2021-11-02     Correa, Carlos  621043   519293  field_out
# 8          FF 2021-11-02  Brantley, Michael  488726   519293     single
# 62         CH 2021-11-02     Rosario, Eddie  592696   554340  field_out
#
#       description stand p_throws home_team  ... estimated_ba_using_speedangle  \
# 26  hit_into_play     R        L       HOU  ...                         0.071
# 29  hit_into_play     L        L       HOU  ...                         0.026
# 28  hit_into_play     R        L       HOU  ...                         0.149
# 8   hit_into_play     L        L       HOU  ...                         0.871
# 62  hit_into_play     L        R       HOU  ...                         0.069
#
#    estimated_woba_using_speedangle  launch_speed_angle at_bat_number  \
# 26                           0.064                   2            69
# 29                           0.046                   3            68
# 28                           0.182                   3            67
# 8                            0.855                   4            66
# 62                           0.063                   2            65
#
#     pitch_number       pitch_name  bat_score  fld_score  \
# 26             3  4-Seam Fastball          0          7
# 29             6  4-Seam Fastball          0          7
# 28             4  4-Seam Fastball          0          7
# 8              6  4-Seam Fastball          0          7
# 62             2         Changeup          7          0
#
#     if_fielding_alignment  of_fielding_alignment
# 26               Standard               Standard
# 29          Infield shift               Standard
# 28          Infield shift               Standard
# 8           Infield shift               Standard
# 62          Infield shift               Standard
#
# [5 rows x 39 columns]

# %%
df_core_stats.shape
# Out:
# (123150, 39)

# %%
df_core_stats.to_csv('2021_batted_ball_data.csv')
